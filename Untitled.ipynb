# %%
pip show jupyter_contrib_nbextensions
# Out:
# Name: jupyter-contrib-nbextensions
# Version: 0.5.1
# Summary: A collection of Jupyter nbextensions.
# Home-page: https://github.com/ipython-contrib/jupyter_contrib_nbextensions.git
# Author: ipython-contrib and jupyter-contrib developers
# Author-email: jupytercontrib@gmail.com
# License: BSD
# Location: /Users/mahi/opt/anaconda3/lib/python3.7/site-packages
# Requires: nbconvert, jupyter-core, jupyter-contrib-core, jupyter-highlight-selected-word, notebook, lxml, traitlets, jupyter-nbextensions-configurator, ipython-genutils, tornado, jupyter-latex-envs, pyyaml
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jupyter contrib nbextensions install
# Out:
# [I 17:05:46 InstallContribNbextensionsApp] jupyter contrib nbextension install
# [I 17:05:46 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 17:05:46 InstallContribNbextensionsApp] Installing /Users/mahi/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 17:05:46 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/rubberband/icon.png
# [I 17:05:46 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/rubberband/main.css
# [I 17:05:46 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/rubberband/readme.md
# [I 17:05:46 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/rubberband/main.js
# [I 17:05:46 InstallContribNbextensionsApp] Up to date: /usr/local/share/jupyter/nbextensions/rubberband/rubberband.yaml
# ...
